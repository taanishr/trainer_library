# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import scipy.integrate as integrate
from scipy.optimize import fsolve
import scipy
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn import svm
import scipy.misc

import graphlearning as gl

import matplotlib.pyplot as plt

# %%
from sklearn import linear_model as linear
from sklearn import metrics as metrics

# %%
from torchvision import datasets, transforms

# %%
import classifier

# %%
mnist = datasets.MNIST("/home/taanish/MNIST", train=True, download=False)

# %%
X = mnist.data.numpy()[:10000,:28,:28]

# %%
X = np.reshape(X, (10000, 784))

# %%
labels = mnist.targets.numpy()[:10000]

# %%
cl = classifier.ClassificationTests(X, labels, 500, 10000)

# %%
cl.train(50)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cl.train(50)
#
# File ~/trainer_library/classifier.py:41, in ClassificationTests.train(self, nn)
#      40 def train(self, nn: int = 100):
# ---> 41     self.__generate_graphs(nn)
#      42     self.__train_helper()
#      43     self.trained = True
#
# File ~/trainer_library/classifier.py:34, in ClassificationTests.__generate_graphs(self, nn)
#      32 def __generate_graphs(self, nn):
#      33     self.W, self.G, self.L = manifoldlearning.manifoldlearning.generate_knn(self.samples, n_neighbors=nn)
# ---> 34     self.G_l, self.L_l = manifoldlearning.manifoldlearning.partition_knn(self.G, self.label_ind)
#
# File ~/trainer_library/manifoldlearning.py:226, in manifoldlearning.partition_knn(G, ind, normalization)
#     224 l_partition = g_partition.laplacian(normalization=normalization)
#     225 if g_partition.isconnected() == False:
# --> 226     raise Exception("Graph is not connected")
#     227 return g_partition, l_partition
#
# Exception: Graph is not connected

# %%
score_ground = cl.ground_accuracy()

# %%
print(score_ground)
# Out:
# Call train() first

# %%
(score, predict) = cl.OOSE_accuracy()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 (score, predict) = cl.OOSE_accuracy()
#
# File ~/trainer_library/classifier.py:54, in ClassificationTests.OOSE_accuracy(self)
#      52     return Exception("Call train() first")
#      53 o = manifoldlearning.OOSE(self.samples, self.label_ind)
# ---> 54 (self.X0, self.OOSE_embeddings, d_tests) = o.embed(r=self.r, W=self.W, L=self.L, vecs=self.eigs, vals=self.ev)
#      55 self.score = self.classifier.score(X=self.OOSE_embeddings, y=self.labels[self.unlabel_ind])
#      56 self.predict = self.classifier.predict(X=self.OOSE_embeddings)
#
# File ~/trainer_library/manifoldlearning.py:184, in OOSE.embed(self, r, c0, beta, start, stop, num, W, L, vecs, vals)
#     183 def embed(self, r: int = 10, c0: int = 2., beta: float = 0.9, start: int = 0, stop: int = 100, num: int = 40, W = None, L = None, vecs=None, vals=None):
# --> 184     self.init(r, c0, W=W, L=L, vecs=vecs, vals=vals)
#     185     (self.OOSE_embeddings, *dtests) = self.optim(beta, start, stop, num)
#     186     return self.X0, self.OOSE_embeddings, dtests
#
# File ~/trainer_library/manifoldlearning.py:151, in OOSE.init(self, r, c0, W, L, vecs, vals)
#     149 A_ = scipy.sparse.linalg.LinearOperator(L_22.shape, self.A)
#     150 X = np.random.randn(self.B.shape[0], r) # randomly initialized approximation for eigenvectors
# --> 151 l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
#     152                                 verbosityLevel=0,
#     153                                 maxiter=1000) # solve generalized eigenproblem
#     155 eigenVectors = Vg
#     156 eigenValues = l
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:791, in lobpcg(A, X, B, M, Y, tol, maxiter, largest, verbosityLevel, retLambdaHistory, retResidualNormsHistory, restartControl)
#     784     warnings.warn(
#     785         f"Failed at iteration {iterationNumber} with accuracies "
#     786         f"{residualNorms}\n not reaching the requested "
#     787         f"tolerance {residualTolerance}.",
#     788         UserWarning, stacklevel=2
#     789     )
#     790     break
# --> 791 activeBlockVectorAR = A(activeBlockVectorR)
#     793 if iterationNumber > 0:
#     794     if B is not None:
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:64, in _makeMatMat.<locals>.<lambda>(v)
#      62     return None
#      63 elif callable(m):
# ---> 64     return lambda v: m(v)
#      65 else:
#      66     return lambda v: m @ v
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:408, in LinearOperator.__call__(self, x)
#     407 def __call__(self, x):
# --> 408     return self*x
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:411, in LinearOperator.__mul__(self, x)
#     410 def __mul__(self, x):
# --> 411     return self.dot(x)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:446, in LinearOperator.dot(self, x)
#     444     return self.matvec(x)
#     445 elif x.ndim == 2:
# --> 446     return self.matmat(x)
#     447 else:
#     448     raise ValueError('expected 1-d or 2-d array or matrix, got %r'
#     449                      % x)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:340, in LinearOperator.matmat(self, X)
#     337     raise ValueError(f'dimension mismatch: {self.shape}, {X.shape}')
#     339 try:
# --> 340     Y = self._matmat(X)
#     341 except Exception as e:
#     342     if issparse(X) or is_pydata_spmatrix(X):
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:590, in _CustomLinearOperator._matmat(self, X)
#     588     return self.__matmat_impl(X)
#     589 else:
# --> 590     return super()._matmat(X)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:191, in LinearOperator._matmat(self, X)
#     184 def _matmat(self, X):
#     185     """Default matrix-matrix multiplication handler.
#     186
#     187     Falls back on the user-defined _matvec method, so defining that will
#     188     define matrix multiplication (though in a very suboptimal way).
#     189     """
# --> 191     return np.hstack([self.matvec(col.reshape(-1,1)) for col in X.T])
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:236, in LinearOperator.matvec(self, x)
#     233 if x.shape != (N,) and x.shape != (N,1):
#     234     raise ValueError('dimension mismatch')
# --> 236 y = self._matvec(x)
#     238 if isinstance(x, np.matrix):
#     239     y = asmatrix(y)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/scipy/sparse/linalg/_interface.py:593, in _CustomLinearOperator._matvec(self, x)
#     592 def _matvec(self, x):
# --> 593     return self.__matvec_impl(x)
#
# File ~/trainer_library/manifoldlearning.py:139, in OOSE.init.<locals>.<lambda>(x)
#     137 #o = 1/jnp.sqrt(self.n)*om2
#     138 P = lambda x : x - o@(o.T@x)
# --> 139 self.A = lambda x : P(L_22@P(x))
#     142 self.B = P(1/self.m2 * L_22@om2@c1.T +  L[ul_ind][:,self.label_ind]@X1) # Second matrix is L_21 (labelled to unlabelled)
#     144 '''
#     145 Calculate eigenvectors of A
#     146 Randomly initializes approximation eigenvectors,
#     147 then uses LOBPCG to solve generalized eigenproblem (which starts with approximation)
#     148 '''
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/transform.py:466, in _sparsify_with_interpreter.<locals>.wrapped(*args, **params)
#     464 spenv = SparsifyEnv()
#     465 spvalues = arrays_to_spvalues(spenv, args)
# --> 466 spvalues_out, out_tree = f_raw(spenv, *spvalues, **params)
#     467 out = spvalues_to_arrays(spenv, spvalues_out)
#     468 return tree_unflatten(out_tree, out)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/transform.py:451, in sparsify_raw.<locals>.wrapped(spenv, *spvalues, **params)
#     449 wrapped_fun, out_tree = flatten_fun_nokwargs(lu.wrap_init(f, params), in_tree)
#     450 jaxpr, out_avals_flat, consts, () = pe.trace_to_jaxpr_dynamic(wrapped_fun, in_avals_flat)
# --> 451 result = eval_sparse(jaxpr, consts, spvalues_flat, spenv)
#     452 if len(out_avals_flat) != len(result):
#     453   raise Exception("Internal: eval_sparse does not return expected number of arguments. "
#     454                   "Got {result} for avals {out_avals_flat}")
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/transform.py:428, in eval_sparse(jaxpr, consts, spvalues, spenv)
#     426   if prim not in sparse_rules_bcoo:
#     427     _raise_unimplemented_primitive(prim)
# --> 428   out = sparse_rules_bcoo[prim](spenv, *invals, **eqn.params)
#     429 else:
#     430   out_bufs = prim.bind(*(spenv.data(val) for val in invals), **eqn.params)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/transform.py:539, in _standard_sparse_rule.<locals>._sparse_rule(spenv, *spvalues, **kwds)
#     538 def _sparse_rule(spenv, *spvalues, **kwds):
# --> 539   result = sparse_op(*spvalues_to_arrays(spenv, spvalues), **kwds)
#     540   return arrays_to_spvalues(spenv, result if prim.multiple_results else [result])
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/bcoo.py:640, in bcoo_dot_general(***failed resolving arguments***)
#     638   return BCOO(bufs, shape=shape)
#     639 elif isinstance(lhs, BCOO):
# --> 640   return _bcoo_dot_general(lhs.data, lhs.indices, rhs, dimension_numbers=dimension_numbers,  # type: ignore[arg-type]
#     641                            preferred_element_type=preferred_element_type,
#     642                            lhs_spinfo=lhs._info)
#     643 elif isinstance(rhs, BCOO):
#     644   return _bcoo_rdot_general(lhs, rhs.data, rhs.indices, dimension_numbers=dimension_numbers,
#     645                             preferred_element_type=preferred_element_type,
#     646                             rhs_spinfo=rhs._info)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/experimental/sparse/bcoo.py:662, in _bcoo_dot_general(lhs_data, lhs_indices, rhs, dimension_numbers, preferred_element_type, lhs_spinfo)
#     660 if preferred_element_type is not None:
#     661   preferred_element_type = np.dtype(preferred_element_type)
# --> 662 return bcoo_dot_general_p.bind(jnp.asarray(lhs_data), jnp.asarray(lhs_indices), jnp.asarray(rhs),
#     663                                dimension_numbers=(cdims, bdims),
#     664                                preferred_element_type=preferred_element_type,
#     665                                lhs_spinfo=lhs_spinfo)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/_src/core.py:416, in Primitive.bind(self, *args, **params)
#     413 def bind(self, *args, **params):
#     414   assert (not config.enable_checks.value or
#     415           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 416   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/_src/core.py:420, in Primitive.bind_with_trace(self, trace, args, params)
#     418 def bind_with_trace(self, trace, args, params):
#     419   with pop_level(trace.level):
# --> 420     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     421   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/_src/core.py:921, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     919   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     920 else:
# --> 921   return primitive.impl(*tracers, **params)
#
# File ~/.conda/envs/manifold-learning/lib/python3.12/site-packages/jax/_src/dispatch.py:87, in apply_primitive(prim, *args, **params)
#      85 prev = lib.jax_jit.swap_thread_local_state_disable_jit(False)
#      86 try:
# ---> 87   outs = fun(*args)
#      88 finally:
#      89   lib.jax_jit.swap_thread_local_state_disable_jit(prev)
#
# KeyboardInterrupt:

# %%
subplots = np.array([[4,6,1]])

# %%
cl.visualize_preds(subplots)

# %%
score
# Out:
# 0.661125

# %%
predict
# Out:
# array([3, 0, 9, ..., 4, 3, 6])

# %%
cl.visualize_pts()

# %%
#from sklearn.neighbors import kneighbors_graph

# %%
#data1 = np.array([[1,2],[3,4],[5,6],[7,8]], np.int32)

# %%
#dg1 = kneighbors_graph(data1, n_neighbors=2)

# %%
#dg1.toarray()

# %%
#data2 = np.array([[7],[9],[6],[12]], np.int32)

# %%
#dg2 = kneighbors_graph(data2, n_neighbors=2)

# %%
#dg2.toarray()

# %%
#print(data1[0])

# %%
#print(data1[0].ndim)

# %%
import knn

# %%
k = knn.KNNTests(X, 10000, 2000)

# %%
k.generate_knns()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [7.53721699e-07 4.47849136e-08 3.09280604e-08 3.08729275e-08
#  2.42501602e-08 1.29386777e-08 3.12400285e-08 1.48007440e-07
#  2.06637429e-05 2.74707473e-04]
# not reaching the requested tolerance 1e-08.
# Use iteration 978 instead with accuracy
# 2.388326066753915e-05.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [1.53038580e-06 6.87743712e-08 6.17123490e-08 8.07670783e-08
#  6.75700215e-08 6.62563834e-08 8.64226725e-08 1.77300944e-07
#  2.58738622e-05 2.10264948e-04]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
overlap = k.knn_overlap()

# %%
print(overlap)
# Out:
# 0.37619875000000086

# %%
import regression

# %%
r = regression.RegressionTests(X, labels, 2000, 10000)

# %%
r.train()

# %%
r.ground_accuracy()
# Out:
# 0.45269699502874083

# %%
(r_score, r_predict) = r.OOSE_accuracy()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [6.55950113e-07 1.36100197e-08 2.05535564e-08 7.41933833e-09
#  1.68784717e-08 3.66639777e-08 1.01030020e-07 2.97006753e-08
#  9.77231640e-08 3.70284689e-05]
# not reaching the requested tolerance 1e-08.
# Use iteration 998 instead with accuracy
# 2.2320598424162777e-06.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [1.23389289e-06 4.88841760e-08 5.14575587e-08 7.96278780e-08
#  4.28077978e-08 7.31587265e-08 1.85609934e-07 1.22721572e-07
#  1.67917544e-07 2.18635216e-05]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
r_score
# Out:
# 0.4239446595232452
