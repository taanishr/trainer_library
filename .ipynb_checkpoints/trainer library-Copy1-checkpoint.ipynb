# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import scipy.integrate as integrate
from scipy.optimize import fsolve
import scipy
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn import svm
import scipy.misc

import graphlearning as gl

import matplotlib.pyplot as plt

# %%
from sklearn import linear_model as linear
from sklearn import metrics as metrics

# %%
from torchvision import datasets, transforms

# %%
import classifier

# %%
mnist = datasets.MNIST("/home/taanish/MNIST", train=True, download=False)

# %%
X = mnist.data.numpy()[:20000,:28,:28]

# %%
X = np.reshape(X, (20000, 784))

# %%
labels = mnist.targets.numpy()[:20000]

# %%
cl = classifier.ClassificationTests(X, labels, 2000, 20000)

# %%
cl.train()
# Out:
# /home/taanish/.conda/envs/manifold-learning/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
score_ground = cl.ground_accuracy()

# %%
print(score_ground)
# Out:
# 0.7245

# %%
(score, predict) = cl.OOSE_accuracy()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [1.07281351e-06 1.11205237e-07 1.04262910e-07 3.51266442e-07
#  2.41568343e-07 9.23644481e-08 9.51051431e-08 5.23275428e-07
#  1.51308213e-06 3.17800785e-03]
# not reaching the requested tolerance 1e-08.
# Use iteration 128 instead with accuracy
# 0.00014647697530280264.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [1.42595381e-04 5.20874447e-06 3.11955910e-06 1.00456935e-05
#  9.04098983e-06 4.57094509e-06 7.71544265e-06 2.14962961e-05
#  4.44933969e-05 1.21248368e-03]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
subplots = np.array([[4,6,1]])

# %%
cl.visualize_preds(subplots)

# %%
score
# Out:
# 0.7355555555555555

# %%
predict
# Out:
# array([3, 0, 9, ..., 1, 9, 2])

# %%
cl.visualize_pts()

# %%
#from sklearn.neighbors import kneighbors_graph

# %%
#data1 = np.array([[1,2],[3,4],[5,6],[7,8]], np.int32)

# %%
#dg1 = kneighbors_graph(data1, n_neighbors=2)

# %%
#dg1.toarray()

# %%
#data2 = np.array([[7],[9],[6],[12]], np.int32)

# %%
#dg2 = kneighbors_graph(data2, n_neighbors=2)

# %%
#dg2.toarray()

# %%
#print(data1[0])

# %%
#print(data1[0].ndim)

# %%
import knn

# %%
k = knn.KNNTests(X, 20000, 2000)

# %%
k.generate_knns()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [5.62960308e-07 1.04827685e-07 1.41118292e-07 9.22394941e-08
#  2.42383696e-07 2.12835184e-07 1.79071616e-07 1.21233458e-07
#  1.86270966e-07 3.64112649e-05]
# not reaching the requested tolerance 1e-08.
# Use iteration 997 instead with accuracy
# 3.523423378667217e-06.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [8.67165350e-07 1.22824538e-06 1.21962401e-06 4.95101901e-07
#  1.18355191e-06 1.23914218e-06 6.07756307e-07 3.45396950e-07
#  1.06993010e-06 3.53192337e-05]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
overlap = k.knn_overlap()

# %%
print(overlap)
# Out:
# 0.2829700000000006

# %%
import regression

# %%
r = regression.RegressionTests(X, labels, 2000, 20000)

# %%
r.train()

# %%
r.ground_accuracy()
# Out:
# 0.4346201569444881

# %%
(r_score, r_predict) = r.OOSE_accuracy()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [5.48327729e-06 1.56611729e-07 3.97101461e-07 4.22874335e-07
#  3.81300546e-07 2.29683098e-07 2.96018217e-07 1.18574257e-07
#  3.48550461e-07 8.41780136e-03]
# not reaching the requested tolerance 1e-08.
# Use iteration 132 instead with accuracy
# 0.00013679260648307624.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [2.30044692e-04 8.09540719e-06 1.91351590e-05 2.17953286e-05
#  1.90278046e-05 1.28297279e-05 1.39591127e-05 1.39093628e-05
#  5.34344568e-05 9.79452820e-04]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
r_score
# Out:
# 0.42993482847011066
