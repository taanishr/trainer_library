# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import scipy.integrate as integrate
from scipy.optimize import fsolve
import scipy
from scipy.spatial.distance import cdist
from sklearn.decomposition import PCA
from sklearn import manifold
from sklearn import svm
import scipy.misc

import graphlearning as gl

import matplotlib.pyplot as plt

# %%
from sklearn import linear_model as linear
from sklearn import metrics as metrics

# %%
from torchvision import datasets, transforms

# %%
import classifier

# %%
mnist = datasets.MNIST("/home/taanish/MNIST", train=True, download=False)

# %%
X = mnist.data.numpy()[:10000,:28,:28]

# %%
X = np.reshape(X, (10000, 784))

# %%
labels = mnist.targets.numpy()[:10000]

# %%
cl = classifier.ClassificationTests(X, labels, 2000, 10000)

# %%
cl.train(100)
# Out:
# /home/taanish/.conda/envs/manifold-learning/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
score_ground = cl.ground_accuracy()

# %%
print(score_ground)
# Out:
# 0.684

# %%
(score, predict) = cl.OOSE_accuracy()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [1.84429719e-06 1.29520659e-08 1.53652845e-07 3.33293728e-08
#  1.80003756e-08 4.10524515e-08 1.36412622e-08 2.08978324e-06
#  9.76414868e-04 4.08666133e-03]
# not reaching the requested tolerance 1e-08.
# Use iteration 131 instead with accuracy
# 0.00013574678503405608.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [1.94886364e-04 2.66987962e-06 1.68905749e-06 2.81275142e-06
#  2.12185786e-06 3.35628364e-06 2.53637060e-06 1.70654198e-05
#  3.81596876e-04 7.44403310e-04]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
subplots = np.array([[4,6,1]])

# %%
cl.visualize_preds(subplots)

# %%
score
# Out:
# 0.697875

# %%
predict
# Out:
# array([3, 4, 1, ..., 5, 8, 6])

# %%
cl.visualize_pts()

# %%
#from sklearn.neighbors import kneighbors_graph

# %%
#data1 = np.array([[1,2],[3,4],[5,6],[7,8]], np.int32)

# %%
#dg1 = kneighbors_graph(data1, n_neighbors=2)

# %%
#dg1.toarray()

# %%
#data2 = np.array([[7],[9],[6],[12]], np.int32)

# %%
#dg2 = kneighbors_graph(data2, n_neighbors=2)

# %%
#dg2.toarray()

# %%
#print(data1[0])

# %%
#print(data1[0].ndim)

# %%
import knn

# %%
k = knn.KNNTests(X, 10000, 2000)

# %%
k.generate_knns()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [7.39079630e-07 3.60359587e-08 4.49888892e-08 1.27974215e-08
#  3.25903352e-08 2.18870880e-08 2.94224304e-08 3.56975888e-07
#  2.23964238e-07 2.58035656e-03]
# not reaching the requested tolerance 1e-08.
# Use iteration 564 instead with accuracy
# 4.52002884272108e-05.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [8.00029814e-07 3.34267151e-08 3.83747257e-08 4.24771330e-08
#  4.47219620e-08 4.86521606e-08 6.50405189e-08 1.65348706e-07
#  1.14840874e-07 4.64873600e-04]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
overlap = k.knn_overlap()

# %%
print(overlap)
# Out:
# 0.16900000000000068

# %%
import regression

# %%
r = regression.RegressionTests(X, labels, 2000, 10000)

# %%
r.train()

# %%
r.ground_accuracy()
# Out:
# 0.4394024010988564

# %%
(r_score, r_predict) = r.OOSE_accuracy()
# Out:
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited at iteration 1000 with accuracies
# [4.55442482e-07 1.77917337e-08 2.00162305e-08 1.81436565e-08
#  2.00826096e-08 1.39423012e-08 8.51484973e-08 4.46952356e-08
#  8.81670461e-08 4.22398186e-03]
# not reaching the requested tolerance 1e-08.
# Use iteration 117 instead with accuracy
# 6.703830168651993e-05.
#
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,
# /home/taanish/trainer_library/manifoldlearning.py:151: UserWarning: Exited postprocessing with accuracies
# [7.92103718e-05 1.73202188e-06 2.02363264e-06 2.28550932e-06
#  1.77535125e-06 2.51362596e-06 2.96247387e-06 2.53007900e-06
#  1.12137621e-04 4.53716116e-04]
# not reaching the requested tolerance 1e-08.
#   l, Vg = scipy.sparse.linalg.lobpcg(A_, X, M=None, tol=1e-8, largest=False,

# %%
r_score
# Out:
# 0.41930963286204614
